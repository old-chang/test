# %% [markdown]
# # 数学函数、字符串和对象
# ## 本章介绍Python函数来执行常见的数学运算
# - 函数是完成一个特殊任务的一组语句，可以理解为一个函数相当于一个小功能，但是在开发中，需要注意一个函数的长度最好不要超过一屏
# - Python中的内置函数是不需要Import导入的
# <img src="../Python/Photo/15.png"></img>

# %%
abs(-10)
# Out:
# 10

# %%
a,b,c,d,e = eval(input('请依次输入5个数以‘，’分割：'))
choose_method = input('请选择你要执行的方式:max,min,pow2_sum')
if choose_method == 'max':
        max_=max(a,b,c,d,e)
        print('最大值是:'+str(max_))
elif choose_method == 'min':
        min_=min(a,b,c,d,e)
        print('最小值是:'+str(min_))
elif choose_method == 'pow2_sum':
        pow_sum_ = pow(a,2) + pow(b,2) + pow(c,2)+pow(d,2)+pow(e,2)
        print(pow_sum_)
print('pow的值是：'+str(pow_sum_))
# Out:
# 请依次输入5个数以‘，’分割：1,2,3,4,5
# 请选择你要执行的方式:max,min,pow2_sumpow2_sum
# 55
# pow的值是：55

# %%
import matplotlib.pyplot as plt
import math
list_ = []
for z in range(-50,50):
    res=1./ (1.+ math.exp(-z))
    list_.append(res)
plt.plot(list_)
plt.show()

# %%
import random
import math
num1=random.random()
res=1./(1.+math.exp(-num1))
round(res)
# Out:
# 1

# %%
math.log(1)
# Out:
# 0.0

# %% [markdown]
# ## 尝试练习Python内置函数

# %% [markdown]
# ## Python中的math模块提供了许多数学函数
# <img src="../Python/Photo/16.png"></img>
# <img src="../Python/Photo/17.png"></img>

# %% [markdown]
# ## 两个数学常量PI和e，可以通过使用math.pi 和math.e调用

# %% [markdown]
# ## EP:
# - 通过math库，写一个程序，使得用户输入三个顶点(x,y)返回三个角度
# - 注意：Python计算角度为弧度制，需要将其转换为角度
# <img src="../Python/Photo/18.png">

# %%
x1,y1 = eval(input('请输入第一个顶点坐标：'))
x2,y2 = eval(input('请输入第二个顶点坐标：'))
x3,y3 = eval(input('请输入第三个顶点坐标：'))
a=math.sqrt((x3-x2)**2+(y3-y2)**2)
b=math.sqrt((x3-x1)**2+(y3-y1)**2)
c=math.sqrt((x2-x1)**2+(y2-y1)**2)
A=math.degrees(math.acos((a*a-b*b-c*c)/(-2*b*c)))
B=math.degrees(math.acos((b*b-a*a-c*c)/(-2*a*c)))
C=math.degrees(math.acos((c*c-b*b-a*a)/(-2*a*b)))

print('A的角度是：'+str(round(A))+'度，B的角度是：'+str(round(B))+'度，C的角度是：'+str(round(C))+'度')
# Out:
# 请输入第一个顶点坐标：2,2
# 请输入第二个顶点坐标：3,3
# 请输入第三个顶点坐标：2,4
# A的角度是：45度，B的角度是：90度，C的角度是：45度

# %% [markdown]
# ## 字符串和字符
# - 在Python中，字符串必须是在单引号或者双引号内，在多段换行的字符串中可以使用“”“
# - 在使用”“”时，给予其变量则变为字符串，否则当多行注释使用

# %% [markdown]
# ## ASCII码与Unicode码
# - <img src="../Python/Photo/19.png"></img>
# - <img src="../Python/Photo/20.png"></img>
# - <img src="../Python/Photo/21.png"></img>

# %% [markdown]
# ## 函数ord、chr
# - ord 返回ASCII码值
# - chr 返回字符

# %%
ord('b')
# Out:
# 98

# %%
chr(98)
# Out:
# 'b'

# %% [markdown]
# ## EP:
# - 利用ord与chr进行简单邮箱加密

# %%
title = '12312213@qq.com'
result=''
for i in title:
    result += chr(ord(i)+10)
print(result)
# Out:
# ;<=;<<;=J{{8myw

# %% [markdown]
# ## 转义序列 \
# - a = "He said,"Johon's program is easy to read"
# - 转掉它原来的意思
# - 一般情况下只有当语句与默认方法相撞的时候，就需要转义

# %%
import hashlib
str_ = 'sds'
h1 = hashlib.md5()
h1.update(str_.encode(encoding='utf-8'))
print('MD5加密前为：'+ str_)
print('MD5加密后为：'+ h1.hexdigest())
# Out:
# MD5加密前为：sds
# MD5加密后为：82d5984c2a2ad4c62caf1dd073b1c91c

# %%
import hashlib
password = '82d5984c2a2ad4c62caf1dd073b1c91c'
login = input('请输入密码：')
h1 = hashlib.md5()
h1.update(login.encode(encoding='utf-8'))
if password==h1.hexdigest():
    print('密码正确')
else:
    print('密码错误')
# Out:
# 请输入密码：123
# 密码错误

# %% [markdown]
# ## 高级print
# - 参数 end： 以什么方式结束打印
# - 默认换行打印

# %%
print('a','b',end='\n')
# Out:
# a b

# %% [markdown]
# ## 函数str
# - 将类型强制转换成字符串类型
# - 其他一些以后会学到(list,set,tuple...)

# %% [markdown]
# ## 字符串连接操作
# - 直接使用 “+”
# - join() 函数

# %% [markdown]
# ## EP：
# - 将 “Welcome” “to” "Python" 拼接
# - 将int型 100 与 “joker is a bad man” 拼接
# - 从控制台读取字符串
# > 输入一个名字返回夸奖此人

# %%
'welcome'+'to'+'Python'
# Out:
# 'welcometoPython'

# %%
# %time 'welcome'+'to'+'Python'
# Out:
# Wall time: 1 ms
# 'welcometoPython'

# %%
# %time '100'.join(['joker','is','a','bad','man'])
# Out:
# Wall time: 0 ns
# 'joker100is100a100bad100man'

# %% [markdown]
# ## 实例研究：最小数量硬币
# - 开发一个程序，让用户输入总金额，这是一个用美元和美分表示的浮点值，返回一个由美元、两角五分的硬币、一角的硬币、五分硬币、以及美分个数
# <img src="../Python/Photo/22.png"></img>

# %% [markdown]
# - Python弱项，对于浮点型的处理并不是很好，但是处理数据的时候使用的是Numpy类型
# <img src="../Python/Photo/23.png"></img>

# %%
num = 1
while num != 0:
    num -= 0.1
    print(num)
    #结果死循环
# Out:
# 0.9
# 0.8
# 0.7000000000000001
# 0.6000000000000001
# 0.5000000000000001
# 0.40000000000000013
# 0.30000000000000016
# 0.20000000000000015
# 0.10000000000000014
# 1.3877787807814457e-16
# -0.09999999999999987
# -0.19999999999999987
# -0.2999999999999999
# -0.3999999999999999
# -0.4999999999999999
# -0.5999999999999999
# -0.6999999999999998
# -0.7999999999999998
# -0.8999999999999998
# -0.9999999999999998
# -1.0999999999999999
# -1.2
# -1.3
# -1.4000000000000001
# -1.5000000000000002
# -1.6000000000000003
# -1.7000000000000004
# -1.8000000000000005
# -1.9000000000000006
# -2.0000000000000004
# -2.1000000000000005
# -2.2000000000000006
# -2.3000000000000007
# -2.400000000000001
# -2.500000000000001
# -2.600000000000001
# -2.700000000000001
# -2.800000000000001
# -2.9000000000000012
# -3.0000000000000013
# -3.1000000000000014
# -3.2000000000000015
# -3.3000000000000016
# -3.4000000000000017
# -3.5000000000000018
# -3.600000000000002
# -3.700000000000002
# -3.800000000000002
# ...

# %% [markdown]
# ## id与type
# - id 查看内存地址，在判断语句中将会使用
# - type 查看元素类型

# %%
id(1)
# Out:
# 1538354656

# %%
a=1
id(a)
# Out:
# 1538354656

# %%
id(2)
# Out:
# 1538354688

# %%
a=2
id(a)
# Out:
# 1538354688

# %%
type('a')
# Out:
# str

# %% [markdown]
# ## 其他格式化语句见书

# %% [markdown]
# # Homework
# - 1
# <img src="../Python/Photo/24.png"><img>
# <img src="../Python/Photo/25.png"><img>

# %%
import math
r = eval(input('请输入顶点到中心的距离：'))
s = 2*r*math.sin(math.pi/5)
Area = 5*s*s/(4*math.tan(math.pi/5))
print('五边形的面积是：'+str(Area))
# Out:
# 请输入顶点到中心的距离：5.5
# 五边形的面积是：71.923649044821

# %% [markdown]
# - 2
# <img src="../Python/Photo/26.png"><img>

# %%
import math
x1,y1 = eval(input('请输入第一个点坐标：'))
x2,y2 = eval(input('请输入第二个点坐标：'))
radius=6371.01
x1=math.radians(x1)
x2=math.radians(x2)
y1=math.radians(y1)
y2=math.radians(y2)
d=radius*math.acos(math.sin(x1)*math.sin(x2)+math.cos(x1)*math.cos(x2)*math.cos(y1-y2))
print('两点之间的距离是：'+str(d)+' km')
# Out:
# 请输入第一个点坐标：39.55,-116.25
# 请输入第二个点坐标：41.5,87.37
# 两点之间的距离是：10691.79183231593 km

# %% [markdown]
# - 3
# <img src="../Python/Photo/27.png"><img>

# %%
import math
s = eval(input('请输入五角形的边长：'))
Area = 5*s*s/(4*math.tan(math.pi/5))
print('五角形的面积是：'+str(Area))
# Out:
# 请输入五角形的边长：5.5
# 五角形的面积是：52.044441367816255

# %% [markdown]
# - 4
# <img src="../Python/Photo/28.png"><img>

# %%
import math
n = eval(input('请输入正多边形的边数：'))
s = eval(input('请输入正多边形的边长：'))
Area = n*s*s/(4*math.tan(math.pi/5))
print('正多边形的面积是：'+str(Area))
# Out:
# 请输入正多边形的边数：5
# 请输入正多边形的边长：6.5
# 正多边形的面积是：72.69017017488386

# %% [markdown]
# - 5
# <img src="../Python/Photo/29.png"><img>
# <img src="../Python/Photo/30.png"><img>

# %%
num1 = int (input('请输入一个0到1000的整数：'))
if 1<num1<127:
    print('ASCII码值'+str(num1)+'对应的字符为：'+ chr(num1))
else :
    print('数字超出范围！！！')
# Out:
# 请输入一个0到1000的整数：69
# ASCII码值69对应的字符为：E

# %% [markdown]
# - 6
# <img src="../Python/Photo/31.png"><img>

# %%
user = input('请输入雇员姓名：')
times = eval(input('请输入一周工作时间：'))
money = eval(input('请输入每小时报酬：'))
rate1 = eval(input('请输入联邦预扣税率：'))
rate2 = eval(input('请输入州预扣税率：'))
Gross = times*money
Federal = Gross*rate1
State = Gross*rate2
Total = Federal+State
Net = Gross-Total
print('雇员姓名：'+str(user)+'\n'+'一周工作时间:'+str(times)+'\n'+'每小时报酬：'+str(money)+'\n'+'获得报酬：'+str(Gross)+'\n'+'   联邦预扣税:'+str(Federal)+'\n'+'   州预扣税:'+str(State)+'\n'+'   总扣税:'+str(Total)+'\n'+'净剩余:'+str(Net))
# Out:
# 请输入雇员姓名：Smith
# 请输入一周工作时间：10
# 请输入每小时报酬：9.75
# 请输入联邦预扣税率：0.20
# 请输入州预扣税率：0.09
# 雇员姓名：Smith
# 一周工作时间:10
# 每小时报酬：9.75
# 获得报酬：97.5
#    联邦预扣税:19.5
#    州预扣税:8.775
#    总扣税:28.275
# 净剩余:69.225

# %% [markdown]
# ## - 7
# <img src="../Python/Photo/32.png"><img>

# %%
num1 = int (input('请输入一个四位整数：'))
if 1000<num1<9999:
    qian=num1//1000
    bai=num1//100-qian*10
    shi=num1//10-num1//100*10
    ge=num1%10
    print(ge,shi,bai,qian,sep='')
else :
    print('数字超出范围！！！')
# Out:
# 请输入一个四位整数：1234
# 4321

# %% [markdown]
# - 8 进阶：
# > 加密一串文本，并将解密后的文件写入本地保存

# %%
import hashlib
str_ =  input('请输入文本：')
h1 = hashlib.md5()
h1.update(str_.encode(encoding='utf-8'))
print('MD5加密后为：'+ h1.hexdigest())
file = h1.hexdigest()   
file_handle=open('../Python/1.txt',mode='w')
file_handle.write(file)
file_handle.close()
print('成功存入')
# Out:
# 请输入文本：21312wawdas
# MD5加密后为：87c4eedbdb142c61f0e4a1c909748654
# 成功存入
